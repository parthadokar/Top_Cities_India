# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\adoka\Downloads\Top_500_cities.csv')

# %%
df
# Out:
#      Global Ranking        City      GEOGRAPHY            STATE/PROVINCE  \
# 0                 1       Tokyo          Japan                     Tokyo
# 1                 2      Boston  United States             Massachusetts
# 2                 3    New York  United States                  New York
# 3                 4      Sydney      Australia                       NSW
# 4                 5   Singapore      Singapore                 Singapore
# ..              ...         ...            ...                       ...
# 495             496  Zaporozhye        Ukraine         Zaporizhia Oblast
# 496             497      Douala       Cameroon  Cameroon Littoral Region
# 497             498     Madurai          India                Tamil Nadu
# 498             499      La Paz        Bolivia         La Paz Department
# 499             500    Khartoum          Sudan                       NaN
#
#        REGION           BLOC  CityID Current City Classification  \
# ...

# %%
df.head()
# Out:
#    Global Ranking       City      GEOGRAPHY STATE/PROVINCE    REGION   BLOC  \
# 0               1      Tokyo          Japan          Tokyo      ASIA  JAPAN
# 1               2     Boston  United States  Massachusetts  AMERICAS    USA
# 2               3   New York  United States       New York  AMERICAS    USA
# 3               4     Sydney      Australia            NSW      ASIA    ANZ
# 4               5  Singapore      Singapore      Singapore      ASIA   ASIA
#
#    CityID Current City Classification  Current Score Change Since 2019  \
# 0    1361                       NEXUS             56               + 1
# 1     167                       NEXUS             56               + 6
# 2     901                       NEXUS             54               - 2
# 3    1300                       NEXUS             53              + 11
# 4    1240                       NEXUS             53                 -
#
#   Post-COVID 5 year Result
# 0                      + 3
# ...

# %%
df.tail()
# Out:
#      Global Ranking        City GEOGRAPHY            STATE/PROVINCE    REGION  \
# 495             496  Zaporozhye   Ukraine         Zaporizhia Oblast  EMERGING
# 496             497      Douala  Cameroon  Cameroon Littoral Region  EMERGING
# 497             498     Madurai     India                Tamil Nadu      ASIA
# 498             499      La Paz   Bolivia         La Paz Department  AMERICAS
# 499             500    Khartoum     Sudan                       NaN  EMERGING
#
#               BLOC  CityID Current City Classification  Current Score  \
# 495        EURASIA    1518                         NaN             27
# 496         AFRICA     350                         NaN             27
# 497          INDIA    1545                         NaN             27
# 498  LATIN AMERICA     702                         NaN             26
# 499         AFRICA     640                         NaN             23
#
#     Change Since 2019 Post-COVID 5 year Result
# ...

# %%
df.columns
# Out:
# Index(['Global Ranking', 'City', 'GEOGRAPHY', 'STATE/PROVINCE', 'REGION',
#        'BLOC', 'CityID', 'Current City Classification', 'Current Score',
#        'Change Since 2019', 'Post-COVID 5 year Result'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Global Ranking               500 non-null    int64
#  1   City                         500 non-null    object
#  2   GEOGRAPHY                    500 non-null    object
#  3   STATE/PROVINCE               334 non-null    object
#  4   REGION                       500 non-null    object
#  5   BLOC                         500 non-null    object
#  6   CityID                       500 non-null    int64
#  7   Current City Classification  480 non-null    object
#  8   Current Score                500 non-null    int64
#  9   Change Since 2019            500 non-null    object
#  10  Post-COVID 5 year Result     500 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 43.1+ KB

# %%
df.describe()
# Out:
#        Global Ranking       CityID  Current Score
# count      500.000000   500.000000     500.000000
# mean       250.500000   877.020000      39.554000
# std        144.481833   539.987148       5.644715
# min          1.000000     1.000000      23.000000
# 25%        125.750000   393.500000      36.000000
# 50%        250.500000   850.500000      40.000000
# 75%        375.250000  1328.750000      43.000000
# max        500.000000  2112.000000      56.000000

# %%
df.shape
# Out:
# (500, 11)

# %%
df.isnull().sum()
# Out:
# Global Ranking                   0
# City                             0
# GEOGRAPHY                        0
# STATE/PROVINCE                 166
# REGION                           0
# BLOC                             0
# CityID                           0
# Current City Classification     20
# Current Score                    0
# Change Since 2019                0
# Post-COVID 5 year Result         0
# dtype: int64

# %%
df['GEOGRAPHY'].value_counts().head(10)
# Out:
# United States     118
# China              40
# Germany            22
# France             20
# Russia             20
# United Kingdom     17
# Canada             14
# Australia          13
# India              13
# Japan              12
# Name: GEOGRAPHY, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.countplot(df['GEOGRAPHY'],data=df)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\adoka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_india = df[(df['GEOGRAPHY'] == 'India')]

# %%
df_india
# Out:
#      Global Ranking       City GEOGRAPHY  STATE/PROVINCE REGION   BLOC  \
# 260             261     Mumbai     India     Maharashtra   ASIA  INDIA
# 293             294  Bangalore     India       Karnataka   ASIA  INDIA
# 343             344      Delhi     India           Delhi   ASIA  INDIA
# 389             390    Chennai     India      Tamil Nadu   ASIA  INDIA
# 394             395  Hyderabad     India  Andhra Pradesh   ASIA  INDIA
# 430             431    Kolkata     India     West Bengal   ASIA  INDIA
# 433             434  Ahmedabad     India         Gujarat   ASIA  INDIA
# 435             436       Pune     India     Maharashtra   ASIA  INDIA
# 472             473     Jaipur     India       Rajasthan   ASIA  INDIA
# 474             475      Surat     India         Gujarat   ASIA  INDIA
# 486             487    Lucknow     India   Uttar Pradesh   ASIA  INDIA
# 494             495     Kanpur     India   Uttar Pradesh   ASIA  INDIA
# ...

# %%
df_india['STATE/PROVINCE'].unique()
# Out:
# array(['Maharashtra', 'Karnataka', 'Delhi', 'Tamil Nadu',
#        'Andhra Pradesh', 'West Bengal', 'Gujarat', 'Rajasthan',
#        'Uttar Pradesh'], dtype=object)

# %%
df_india['Current Score'].unique()
# Out:
# array([39, 38, 37, 35, 33, 30, 28, 27], dtype=int64)

# %%
# Best Score
df_india[(df_india['Current Score'] == 28)]
# Out:
#      Global Ranking     City GEOGRAPHY STATE/PROVINCE REGION   BLOC  CityID  \
# 486             487  Lucknow     India  Uttar Pradesh   ASIA  INDIA     749
#
#     Current City Classification  Current Score Change Since 2019  \
# 486                         NaN             28              - 51
#
#     Post-COVID 5 year Result
# 486                     - 62

# %%
# Best in India
df_india[(df_india['Global Ranking'] == 261)]
# Out:
#      Global Ranking    City GEOGRAPHY STATE/PROVINCE REGION   BLOC  CityID  \
# 260             261  Mumbai     India    Maharashtra   ASIA  INDIA     862
#
#     Current City Classification  Current Score Change Since 2019  \
# 260                        NODE             39             - 176
#
#     Post-COVID 5 year Result
# 260                    - 176
